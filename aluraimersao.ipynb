# %% [markdown]
# # Aula 1

# %%
import pandas as pd
url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ## Mostrando valores únicos

# %%
dados["tratamento"].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados["tempo"].unique()
# Out:
# array([24, 72, 48])

# %%
dados["dose"].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados["droga"].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# O nome das drogas foram escondidos, provavelmente para não ter vies na analise dos dados

# %%
dados["g-0"].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados["tratamento"].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# Número de dados com_droga desproporcional aos sem

# %% [markdown]
# ### Desafio 1: Por quê a classe tratamento é tão desbalanceada
# ### Desafio 2: Plotar as 5 últimas linhas da tabela

# %%
# DESAFIO 02
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Desafio 3: Proporção das classes tratamento

# %%
dados["tratamento"].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Isso mostra que 92,2% dos dados são com_drogas e 7,8% são sem

# %% [markdown]
# ## Desafio 4: Quantos tipos de drogas foram investigadas?

# %%
dados["droga"].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# ba08ac4bc       1
# 547f80a41       1
# b01cf573a       1
# 18a406358       1
# 0dedfb162       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# ### Ainda contando dados

# %%
dados["dose"].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados["dose"].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# ### Plotando gráficos

# %%
dados["tratamento"].value_counts().plot.pie()

# %%
dados["tempo"].value_counts().plot.pie()

# %% [markdown]
# Gráficos em pizza não são muito uteis para mostrar valores a olho nu, é melhor evitá-los.

# %%
x = dados["tempo"].value_counts().plot.bar(title = "Quantidade de testes por hora")

# %%
dados_filtrados = dados[dados["g-0"] > 0]

# %% [markdown]
# ## Desafio 5: Procurar na documentação o query

# %%
filtrado_dados = dados.query("g-0 > 0")
filtrado_dados
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     187             if self.has_resolvers:
# --> 188                 return self.resolvers[key]
#     189
#
# /usr/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# /usr/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'g'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## Desafio 6: Renomear as colunas tirando o hífen
# ## Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)
# ## Desafio 08: Resumo do que você aprendeu com os dados

# %%
dados.rename(columns = lambda x : x.replace("-", " "), inplace= True)
dados

# %% [markdown]
# ## Resumo Aula 1
# Os dados são de alguma base de teste de drogas em diferentes celulas, além do tipo de droga variar, também varia a quantidade de dose e o horário de colheta da informação. Os dados puramente númericos já estáo normalizados e escalonados, apesar de não saber de primeira vista o que realmente representam. A maioria dos testes foram feitos com as droga (92%) e uma pequena parcela serviu como controle. Por fim, ainda resta uma análise mais profunda dos dados e mais informações.

# %% [markdown]
# # Aula 2

# %%
mapa = {"droga": "composto"}
dados.rename(columns=mapa, inplace=True)

# %% [markdown]
# Trocamos o nome da coluna "droga" para "composto" já que descobrimos que não são realmente drogas, mas sim composições de drogas.

# %%
dados.head()

# %%
compostos_principais = dados["composto"].value_counts().index[:5]

# %%
dados_query = dados.query("composto in @compostos_principais")

# %% [markdown]
# Usando a função query, filtramos todos as linhas em que o composto está na lista de top 5 de compostos usados. Logo plotamos os dados desse filtro com o *SEABORN*.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

plt.figure(figsize=(15,10))
grafico = sns.countplot(x = "composto", 
                        data=dados_query, 
                        order= compostos_principais)
grafico.set_title("Top compostos")
plt.show()

# %% [markdown]
# ## Descrevendo os dados

# %%
len(dados["g-0"].unique())

# %%
dados["g-0"].min()

# %%
dados["g-0"].max()

# %% [markdown]
# ### Plotando pelo pandas

# %%
dados["g-0"].hist(bins=100)

# %%
dados.describe()

# %%
dados[["g-0", "g-1"]].describe()

# %%
dados.loc[:, "g-0": "g-771"].describe()

# %% [markdown]
# Plotaremos as colunas de "g-0" até "g-771" em relação a média, min, max etc. Por isso, fazemos a transposta do describe().

# %%
dados.loc[:, "g-0": "g-771"].describe().T["mean"].hist(bins=50)
plt.show()

# %%
dados.loc[:, "g-0": "g-771"].describe().T["min"].hist(bins=50)
plt.show()

# %%
dados.loc[:, "g-0": "g-771"].describe().T["max"].hist(bins=50)
plt.show()

# %%
dados.loc[:, "c-0": "c-99"].describe().T["mean"].hist(bins=50)
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x = "tratamento", y = "g-0", data = dados)
plt.show()

# %% [markdown]
# # AULA 3

# %%
pd.crosstab(dados["dose"], dados["tempo"])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %% [markdown]
# Mas queremos saber mais a fundo a quantidade de tratamento com droga e com controle.

# %%
pd.crosstab([dados["dose"], dados["tempo"]], dados["tratamento"])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# Para sabermos a frequência dos dados conforme a cada tempo e dose.

# %%
pd.crosstab([dados["dose"], dados["tempo"]], dados["tratamento"], normalize="index")
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados["dose"], dados["tempo"]], dados["tratamento"], values=dados["g-0"], aggfunc="mean")
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
import seaborn as sns

sns.scatterplot(x = "g-0", y = "g-3", data = dados)

# %%
sns.scatterplot(x = "g-0", y = "g-8", data = dados)

# %%
sns.lmplot(x = "g-0", y = "g-8", data = dados, line_kws = {"color": "red"})

# %%
sns.lmplot(x = "g-0", y = "g-8", data = dados, line_kws = {"color": "red"}, col = "tratamento", row = "tempo")

# %% [markdown]
# Podemos ver que conforme o tempo aumenta a inclinação da reta aumenta, significando que o coeficiênte angular aumenta. Também percebe-se que o grupo de controle não tem alteração, como o esperado.

# %%
dados.loc[:, "g-0": "g-771"].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = dados.loc[:, "g-0": "g-50"].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Compute the correlation matrix
corr_c = dados.loc[:, "c-0": "c-50"].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_c, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_c, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Resumo
#   Os valores géneticos têm uma grande diferença de correlação entre eles. Isso indica que alguns são inversamente proporcionais e outros igualmente proporcionais. Já os valores das celulas aparentam ser todos altamente correlacionados. Os valores das celulas são a quantidade de celulas sobreviventes ao composto aplicado.

# %% [markdown]
# # Aula 4

# %%
dados_resultados = pd.read_csv("https://github.com/alura-cursos/imersao-dados-desafio-final/blob/main/Dados/dados_resultados.csv?raw=true")
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados["acat_inhibitor"].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes("int64").sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop("id", axis  = 1).sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados["n_moa"] = dados_resultados.drop("id", axis  = 1).sum(axis = 1)

# %%
dados_resultados["ativo_moa"] = (dados_resultados["n_moa"] != 0)

# %% [markdown]
# Criamos duas novas colunas para indicar a quantidade de componentes usados e se foi ativo.

# %%
dados_combinados = pd.merge(dados, dados_resultados[["id", "n_moa", "ativo_moa"]], on = "id")
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query("tratamento == 'com_controle'")["ativo_moa"].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query("tratamento == 'com_droga'")["ativo_moa"].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16,12))
composto_principal = dados_combinados["droga"].value_counts().index[:5]
sns.boxplot(data = dados_combinados.query("droga in @composto_principal"), y="g-0", x="droga", hue = "ativo_moa")

# %% [markdown]
# # Aula 5

# %% [markdown]
# ## logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import  train_test_split

# Separando os parametros e os labels
y = dados_combinados["ativo_moa"]
x = dados_combinados.select_dtypes("float64")

# Separando os dados de treino e teste
X_treino, X_teste, y_treino, y_teste = train_test_split(x,
                                                        y,
                                                        test_size = 0.2,
                                                        stratify = y,
                                                        random_state= 2)

# Criando o modelo com Regressão Logística
modelo_LogReg = LogisticRegression(max_iter= 1000)
modelo_LogReg.fit(X_treino, y_treino) 

# Vizualizando a precissão
modelo_LogReg.score(X_teste, y_teste)
# Out:
# 0.6197774511862272

# %%
# Usando um dummy
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier("most_frequent") # Vai escolher o classificador mais frequente com dummy
modelo_dummy.fit(X_treino, y_treino)

# Prevendo
previsao_dummy = modelo_dummy.predict(X_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Separando os parametros e os labels
y = dados_combinados["ativo_moa"]
x = dados_combinados.select_dtypes("float64")

# Separando os dados de treino e teste
X_treino, X_teste, y_treino, y_teste = train_test_split(x,
                                                        y,
                                                        test_size = 0.2,
                                                        stratify = y,
                                                        random_state= 2)

# Criando o modelo com Árvore de decisão
modelo_tree = DecisionTreeClassifier(max_depth=3)
modelo_tree.fit(X_treino, y_treino) 

# Vizualizando a precissão
modelo_tree.score(X_teste, y_teste)
# Out:
# 0.6090699139197985

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15, 10), facecolor='k')
tree.plot_tree(modelo_tree,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=X_treino.columns,
               class_names=['Não Ativado', 'Ativado'])

plt.show()

# %%
treino, teste = [], []

for i in range(1,15):
  # Criando o modelo com Árvore de decisão
  modelo_tree = DecisionTreeClassifier(max_depth= i)
  modelo_tree.fit(X_treino, y_treino) 
  
  # Vizualizando a precissão
  teste.append(modelo_tree.score(X_teste, y_teste))
  treino.append(modelo_tree.score(X_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6090699139197985,
#  0.6170480789418433,
#  0.6187276926306949,
#  0.6166281755196305,
#  0.6241864371194625,
#  0.6206172580306529,
#  0.6214570648750787,
#  0.6180978374973756,
#  0.6183077892084821,
#  0.6157883686752047,
#  0.6078102036531597,
#  0.6084400587864791]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6214896855808094,
#  0.6313054432838171,
#  0.6384966668416356,
#  0.6498346543488531,
#  0.6655818592199885,
#  0.6781271324339929,
#  0.695659020523857,
#  0.7178625793921579,
#  0.7402236103091702,
#  0.7633195107868354,
#  0.7875702062883838,
#  0.8083040260353788]

# %%
sns.lineplot(x = range(1, 15), y = teste, label="teste")
sns.lineplot(x = range(1, 15), y = treino, label="treino")

# %% [markdown]
# Esses dados demonstram um **OVERFITTING** do modelo.

# %% [markdown]
# ## Random Forest

# %%
# Transformando string em dados binarios
pd.get_dummies(dados_combinados, columns= ["dose", "tratamento", "tempo"])
# Out:
#                  id      droga     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# Separando os parametros e os labels
y = dados_combinados["ativo_moa"]
x = dados_combinados.drop(["id", "n_moa", "ativo_moa", "droga"], axis = 1)
x = pd.get_dummies(x, columns= ["dose", "tratamento", "tempo"])

# Separando os dados de treino e teste
X_treino, X_teste, y_treino, y_teste = train_test_split(x,
                                                        y,
                                                        test_size = 0.2,
                                                        stratify = y,
                                                        random_state= 2)

# Criando o modelo com Random Forest
modelo_floresta = RandomForestClassifier()
modelo_floresta.fit(X_treino, y_treino) 

# Vizualizando a precissão
modelo_floresta.score(X_teste, y_teste)
# Out:
# 0.684232626495906
